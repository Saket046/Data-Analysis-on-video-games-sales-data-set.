# %%
#importing libararies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# from pandas_profiling import ProfileReport

# %% [markdown]
# # besic data exploration

# %%
df=pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.set_index('Rank', inplace=True)
df
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 1            Sports    Nintendo     41.49     29.02      3.77         8.46
# 2          Platform    Nintendo     29.08      3.58      6.81         0.77
# 3            Racing    Nintendo     15.85     12.88      3.79         3.31
# 4            Sports    Nintendo     15.75     11.01      3.28         2.96
# 5      Role-Playing    Nintendo     11.27      8.89     10.22         1.00
# ...             ...         ...       ...       ...       ...          ...
# 16596      Platform       Kemco      0.01      0.00      0.00         0.00
# 16597       Shooter  Infogrames      0.01      0.00      0.00         0.00
# 16598        Racing  Activision      0.00      0.00      0.00         0.00
# 16599        Puzzle    7G//AMES      0.00      0.01      0.00         0.00
# 16600      Platform     Wanadoo      0.01      0.00      0.00         0.00
#
#        Global_Sales
# Rank
# 1             82.74
# 2             40.24
# 3             35.82
# 4             33.00
# 5             31.37
# ...             ...
# 16596          0.01
# 16597          0.01
# 16598          0.01
# 16599          0.01
# 16600          0.01
#
# [16598 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
#cleaning data
df=df.replace({
    np.NaN: 'not known'
})

# %%
df.isnull().sum()
# Out:
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df.describe()
# Out:
#                                Name Platform     Year   Genre  \
# count                         16598    16598  16598.0   16598
# unique                        11493       31     40.0      12
# top     Need for Speed: Most Wanted       DS   2009.0  Action
# freq                             12     2163   1431.0    3316
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# count             16598   16598.0   16598.0   16598.0      16598.0
# unique              579     409.0     305.0     244.0        157.0
# top     Electronic Arts       0.0       0.0       0.0          0.0
# freq               1351    4499.0    5730.0   10455.0       6477.0
#
#         Global_Sales
# count       16598.00
# unique        623.00
# top             0.02
# freq         1071.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16598 non-null  object
#  3   Genre         16598 non-null  object
#  4   Publisher     16598 non-null  object
#  5   NA_Sales      16598 non-null  object
#  6   EU_Sales      16598 non-null  object
#  7   JP_Sales      16598 non-null  object
#  8   Other_Sales   16598 non-null  object
#  9   Global_Sales  16598 non-null  object
# dtypes: object(10)
# memory usage: 1.4+ MB

# %%
####understanding pandas profiling
#profile=ProfileReport(df, title='pandas profiling',html={'style':{'full_widht': True}})

# %%
#profile

# %% [markdown]
# # data cleaning

# %%
#checking data types
datatype=df.dtypes
datatype
# Out:
# Name            object
# Platform        object
# Year            object
# Genre           object
# Publisher       object
# NA_Sales        object
# EU_Sales        object
# JP_Sales        object
# Other_Sales     object
# Global_Sales    object
# dtype: object

# %%
df['NA_Sales']=pd.to_numeric(df['NA_Sales'])
df['EU_Sales']=pd.to_numeric(df['EU_Sales'])
df['JP_Sales']=pd.to_numeric(df['JP_Sales'])
df['Other_Sales']=pd.to_numeric(df['Other_Sales'])
df['Global_Sales']=pd.to_numeric(df['Global_Sales'])

# %%
datatype=df.dtypes
datatype
# Out:
# Name             object
# Platform         object
# Year             object
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#df['Year']=df['Year'].astype('int64')
#so we have not known as a record in year which can't be changed into int, thus will generate a error

# %%
####getting years that have not known as record.
wrongdata=df[df['Year']=='not known']
wrongdata
# Out:
#                               Name Platform       Year         Genre  \
# Rank
# 180                Madden NFL 2004      PS2  not known        Sports
# 378               FIFA Soccer 2004      PS2  not known        Sports
# 432     LEGO Batman: The Videogame      Wii  not known        Action
# 471     wwe Smackdown vs. Raw 2006      PS2  not known      Fighting
# 608                 Space Invaders     2600  not known       Shooter
# ...                            ...      ...        ...           ...
# 16310                Freaky Flyers       GC  not known        Racing
# 16330                    Inversion       PC  not known       Shooter
# 16369  Hakuouki: Shinsengumi Kitan      PS3  not known     Adventure
# 16430                 Virtua Quest       GC  not known  Role-Playing
# 16496                   The Smurfs      3DS  not known        Action
#
#                                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# 180                           Electronic Arts      4.26      0.26      0.01
# 378                           Electronic Arts      0.59      2.36      0.04
# 432    Warner Bros. Interactive Entertainment      1.86      1.02      0.00
# 471                                 not known      1.57      1.02      0.00
# 608                                     Atari      2.36      0.14      0.00
# ...                                       ...       ...       ...       ...
# 16310                                 Unknown      0.01      0.00      0.00
# 16330                      Namco Bandai Games      0.01      0.00      0.00
# 16369                                 Unknown      0.01      0.00      0.00
# 16430                                 Unknown      0.01      0.00      0.00
# 16496                                 Unknown      0.00      0.01      0.00
#
#        Other_Sales  Global_Sales
# Rank
# 180           0.71          5.23
# 378           0.51          3.49
# 432           0.29          3.17
# 471           0.41          3.00
# 608           0.03          2.53
# ...            ...           ...
# 16310         0.00          0.01
# 16330         0.00          0.01
# 16369         0.00          0.01
# 16430         0.00          0.01
# 16496         0.00          0.01
#
# [271 rows x 10 columns]

# %%
#we will drop these 271 rows.
df[df['Year']=='not known']=np.nan
df.dropna(axis=0,inplace=True)

# %%
df[df['Year']=='not known']
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df['Year']=df['Year'].astype('int64')

# %%
datatype=df.dtypes
datatype
# Out:
# Name             object
# Platform         object
# Year              int64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.head()
# Out:
#                           Name Platform  Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74
# 2        29.08      3.58      6.81         0.77         40.24
# 3        15.85     12.88      3.79         3.31         35.82
# 4        15.75     11.01      3.28         2.96         33.00
# 5        11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# # top 10 companies in terms of sales???

# %%
##creating a column which have total sales 
df['Total_Sales']=df['NA_Sales']+df['EU_Sales']+df['JP_Sales']+df['Other_Sales']+df['Global_Sales']
df.head()
# Out:
#                           Name Platform  Year         Genre Publisher  \
# Rank
# 1                   Wii Sports      Wii  2006        Sports  Nintendo
# 2            Super Mario Bros.      NES  1985      Platform  Nintendo
# 3               Mario Kart Wii      Wii  2008        Racing  Nintendo
# 4            Wii Sports Resort      Wii  2009        Sports  Nintendo
# 5     Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Total_Sales
# Rank
# 1        41.49     29.02      3.77         8.46         82.74       165.48
# 2        29.08      3.58      6.81         0.77         40.24        80.48
# 3        15.85     12.88      3.79         3.31         35.82        71.65
# 4        15.75     11.01      3.28         2.96         33.00        66.00
# 5        11.27      8.89     10.22         1.00         31.37        62.75

# %%
toppublisher=df.groupby(['Publisher']).sum()
toppublisher.drop(['Year'],axis=1)
# Out:
#                               NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# 10TACLE Studios                   0.07      0.04      0.00         0.00
# 1C Company                        0.01      0.07      0.00         0.02
# 20th Century Fox Video Games      1.82      0.10      0.00         0.01
# 2D Boy                            0.00      0.03      0.00         0.01
# 3DO                               6.48      3.04      0.00         0.63
# ...                                ...       ...       ...          ...
# imageepoch Inc.                   0.00      0.00      0.04         0.00
# inXile Entertainment              0.02      0.06      0.00         0.01
# mixi, Inc                         0.00      0.00      0.86         0.00
# not known                         5.78      2.43      0.03         0.10
# responDESIGN                      0.09      0.04      0.00         0.01
#
#                               Global_Sales  Total_Sales
# Publisher
# 10TACLE Studios                       0.11         0.22
# 1C Company                            0.10         0.20
# 20th Century Fox Video Games          1.94         3.87
# 2D Boy                                0.04         0.08
# 3DO                                  10.12        20.27
# ...                                    ...          ...
# imageepoch Inc.                       0.04         0.08
# inXile Entertainment                  0.10         0.19
# mixi, Inc                             0.86         1.72
# not known                             8.39        16.73
# responDESIGN                          0.13         0.27
#
# [577 rows x 6 columns]

# %% [markdown]
# # answer -

# %%
####answer of top 10 companies in terms of sales.
toppublisher.sort_values(by=['Total_Sales'],ascending=False).head(10)
# Out:
#                                  Year  NA_Sales  EU_Sales  JP_Sales  \
# Publisher
# Nintendo                      1394666    815.75    418.30    454.99
# Electronic Arts               2686562    584.22    367.38     13.98
# Activision                    1938979    426.01    213.72      6.54
# Sony Computer Entertainment   1367034    265.22    187.55     74.10
# Ubisoft                       1843194    252.81    163.03      7.33
# Take-Two Interactive           827344    220.47    117.95      5.83
# THQ                           1428311    208.60     94.60      5.01
# Konami Digital Entertainment  1650392     88.91     68.62     90.93
# Sega                          1267395    108.78     81.41     56.19
# Namco Bandai Games            1863670     69.38     42.61    126.84
#
#                               Other_Sales  Global_Sales  Total_Sales
# Publisher
# Nintendo                            95.19       1784.43      3568.66
# Electronic Arts                    127.63       1093.39      2186.60
# Activision                          74.79        721.41      1442.47
# Sony Computer Entertainment         80.40        607.28      1214.55
# Ubisoft                             50.16        473.54       946.87
# Take-Two Interactive                55.20        399.30       798.75
# THQ                                 32.11        340.44       680.76
# Konami Digital Entertainment        29.91        278.56       556.93
# Sega                                24.30        270.70       541.38
# Namco Bandai Games                  14.64        253.65       507.12

# %%
top=toppublisher.sort_values(by=['Total_Sales'],ascending=False).head(10)
s=top.xs('Total_Sales', axis=1)
s
# Out:
# Publisher
# Nintendo                        3568.66
# Electronic Arts                 2186.60
# Activision                      1442.47
# Sony Computer Entertainment     1214.55
# Ubisoft                          946.87
# Take-Two Interactive             798.75
# THQ                              680.76
# Konami Digital Entertainment     556.93
# Sega                             541.38
# Namco Bandai Games               507.12
# Name: Total_Sales, dtype: float64

# %%
#plotting a barchart
p1=s.plot(kind='bar',title='Top 10 companies as per total sales')
plt.ylabel('Total Sales ($)')
# Out:
# Text(0, 0.5, 'Total Sales ($)')

# %% [markdown]
# # what is the order of genre of the games in the market ??

# %%
df.groupby(['Genre']).count().sort_values(by=['Total_Sales'],ascending=False)
# Out:
#               Name  Platform  Year  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Genre
# Action        3253      3253  3253       3253      3253      3253      3253
# Sports        2304      2304  2304       2304      2304      2304      2304
# Misc          1710      1710  1710       1710      1710      1710      1710
# Role-Playing  1471      1471  1471       1471      1471      1471      1471
# Shooter       1282      1282  1282       1282      1282      1282      1282
# Adventure     1276      1276  1276       1276      1276      1276      1276
# Racing        1226      1226  1226       1226      1226      1226      1226
# Platform       876       876   876        876       876       876       876
# Simulation     851       851   851        851       851       851       851
# Fighting       836       836   836        836       836       836       836
# Strategy       671       671   671        671       671       671       671
# Puzzle         571       571   571        571       571       571       571
#
#               Other_Sales  Global_Sales  Total_Sales
# Genre
# Action               3253          3253         3253
# Sports               2304          2304         2304
# Misc                 1710          1710         1710
# Role-Playing         1471          1471         1471
# Shooter              1282          1282         1282
# Adventure            1276          1276         1276
# Racing               1226          1226         1226
# Platform              876           876          876
# Simulation            851           851          851
# Fighting              836           836          836
# Strategy              671           671          671
# Puzzle                571           571          571

# %% [markdown]
# # Answer -

# %%
gen=df.groupby(['Genre']).count().sort_values(by=['Total_Sales'],ascending=False)
g=gen.xs('Total_Sales', axis=1)
g
# Out:
# Genre
# Action          3253
# Sports          2304
# Misc            1710
# Role-Playing    1471
# Shooter         1282
# Adventure       1276
# Racing          1226
# Platform         876
# Simulation       851
# Fighting         836
# Strategy         671
# Puzzle           571
# Name: Total_Sales, dtype: int64

# %%
#plotting a graph
p2=g.plot(kind='bar',title='Top 10 genre of Games')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # Top 10 favorite platform for gamers??

# %%
df.groupby(['Platform']).count()
# Out:
#           Name  Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# 2600       116   116    116        116       116       116       116
# 3DO          3     3      3          3         3         3         3
# 3DS        500   500    500        500       500       500       500
# DC          52    52     52         52        52        52        52
# DS        2133  2133   2133       2133      2133      2133      2133
# GB          97    97     97         97        97        97        97
# GBA        811   811    811        811       811       811       811
# GC         542   542    542        542       542       542       542
# GEN         27    27     27         27        27        27        27
# GG           1     1      1          1         1         1         1
# N64        316   316    316        316       316       316       316
# NES         98    98     98         98        98        98        98
# NG          12    12     12         12        12        12        12
# PC         943   943    943        943       943       943       943
# PCFX         1     1      1          1         1         1         1
# PS        1189  1189   1189       1189      1189      1189      1189
# PS2       2127  2127   2127       2127      2127      2127      2127
# PS3       1304  1304   1304       1304      1304      1304      1304
# PS4        336   336    336        336       336       336       336
# PSP       1197  1197   1197       1197      1197      1197      1197
# PSV        412   412    412        412       412       412       412
# SAT        173   173    173        173       173       173       173
# SCD          6     6      6          6         6         6         6
# SNES       239   239    239        239       239       239       239
# TG16         2     2      2          2         2         2         2
# WS           6     6      6          6         6         6         6
# Wii       1290  1290   1290       1290      1290      1290      1290
# WiiU       143   143    143        143       143       143       143
# X360      1235  1235   1235       1235      1235      1235      1235
# XB         803   803    803        803       803       803       803
# XOne       213   213    213        213       213       213       213
#
#           Other_Sales  Global_Sales  Total_Sales
# Platform
# 2600              116           116          116
# 3DO                 3             3            3
# 3DS               500           500          500
# DC                 52            52           52
# DS               2133          2133         2133
# GB                 97            97           97
# GBA               811           811          811
# GC                542           542          542
# GEN                27            27           27
# GG                  1             1            1
# N64               316           316          316
# NES                98            98           98
# NG                 12            12           12
# PC                943           943          943
# PCFX                1             1            1
# PS               1189          1189         1189
# PS2              2127          2127         2127
# PS3              1304          1304         1304
# PS4               336           336          336
# PSP              1197          1197         1197
# PSV               412           412          412
# SAT               173           173          173
# SCD                 6             6            6
# SNES              239           239          239
# TG16                2             2            2
# WS                  6             6            6
# Wii              1290          1290         1290
# WiiU              143           143          143
# X360             1235          1235         1235
# XB                803           803          803
# XOne              213           213          213

# %%
plat=df.groupby(['Platform']).count().sort_values(by=['Total_Sales'],ascending=False).head(10)
plat
# Out:
#           Name  Year  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform
# DS        2133  2133   2133       2133      2133      2133      2133
# PS2       2127  2127   2127       2127      2127      2127      2127
# PS3       1304  1304   1304       1304      1304      1304      1304
# Wii       1290  1290   1290       1290      1290      1290      1290
# X360      1235  1235   1235       1235      1235      1235      1235
# PSP       1197  1197   1197       1197      1197      1197      1197
# PS        1189  1189   1189       1189      1189      1189      1189
# PC         943   943    943        943       943       943       943
# GBA        811   811    811        811       811       811       811
# XB         803   803    803        803       803       803       803
#
#           Other_Sales  Global_Sales  Total_Sales
# Platform
# DS               2133          2133         2133
# PS2              2127          2127         2127
# PS3              1304          1304         1304
# Wii              1290          1290         1290
# X360             1235          1235         1235
# PSP              1197          1197         1197
# PS               1189          1189         1189
# PC                943           943          943
# GBA               811           811          811
# XB                803           803          803

# %% [markdown]
# # Answer -

# %%
f=plat.xs('Total_Sales', axis=1)
f
# Out:
# Platform
# DS      2133
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1235
# PSP     1197
# PS      1189
# PC       943
# GBA      811
# XB       803
# Name: Total_Sales, dtype: int64

# %%
#plotting a graph
p3=f.plot(kind='bar',title='Top 10 platforms')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# # which year was best for game industries??

# %%
df.groupby(['Year']).sum().sort_values(by=['Total_Sales'],ascending=False)
# Out:
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Total_Sales
# Year
# 2008    351.44    184.40     60.26        82.39        678.90      1357.39
# 2009    338.85    191.59     61.89        74.77        667.30      1334.40
# 2007    312.05    160.50     60.29        77.60        611.13      1221.57
# 2010    304.24    176.73     59.49        59.90        600.45      1200.81
# 2006    263.12    129.24     73.73        54.43        521.04      1041.56
# 2011    241.06    167.44     53.04        54.39        515.99      1031.92
# 2005    242.61    121.94     54.28        40.58        459.94       919.35
# 2004    222.59    107.32     41.65        47.29        419.31       838.16
# 2002    216.19    109.74     41.76        27.28        395.52       790.49
# 2013    154.77    125.80     47.59        39.82        368.11       736.09
# 2012    154.96    118.78     51.74        37.82        363.54       726.84
# 2003    193.59    103.81     34.20        26.01        357.85       715.46
# 2014    131.97    125.65     39.46        40.02        337.05       674.15
# 2001    173.98     94.89     39.86        22.76        331.47       662.96
# 2015    102.82     97.71     33.72        30.01        264.44       528.70
# 1998    128.36     66.90     50.04        11.03        256.47       512.80
# 1999    126.06     62.67     52.34        10.05        251.27       502.39
# 2000     94.49     52.75     42.77        11.62        201.56       403.19
# 1997     94.75     48.32     48.87         9.13        200.98       402.05
# 1996     86.76     47.26     57.44         7.69        199.15       398.30
# 1995     24.82     14.90     45.75         2.64         88.11       176.22
# 1994     28.15     14.88     33.99         2.20         79.17       158.39
# 1992     33.87     11.71     28.91         1.65         76.16       152.30
# 1989     45.15      8.44     18.36         1.50         73.45       146.90
# 2016     22.66     26.76     13.70         7.75         70.93       141.80
# 1985     33.73      4.74     14.56         0.92         53.94       107.89
# 1984     33.28      2.10     14.27         0.70         50.36       100.71
# 1990     25.46      7.63     14.88         1.40         49.39        98.76
# 1988     23.87      6.59     15.76         0.99         47.22        94.43
# 1993     15.12      4.65     25.33         0.89         45.98        91.97
# 1986     12.50      2.84     19.81         1.93         37.07        74.15
# 1981     33.40      1.96      0.00         0.32         35.77        71.45
# 1991     12.76      3.95     14.78         0.74         32.23        64.46
# 1982     26.92      1.65      0.00         0.31         28.86        57.74
# 1987      8.46      1.41     11.63         0.20         21.74        43.44
# 1983      7.76      0.80      8.10         0.14         16.79        33.59
# 1980     10.59      0.67      0.00         0.12         11.38        22.76
# 2020      0.27      0.00      0.00         0.02          0.29         0.58
# 2017      0.00      0.00      0.05         0.00          0.05         0.10

# %%
year=df.groupby(['Year']).sum()
y=year.xs('Total_Sales', axis=1)
y
# Out:
# Year
# 1980      22.76
# 1981      71.45
# 1982      57.74
# 1983      33.59
# 1984     100.71
# 1985     107.89
# 1986      74.15
# 1987      43.44
# 1988      94.43
# 1989     146.90
# 1990      98.76
# 1991      64.46
# 1992     152.30
# 1993      91.97
# 1994     158.39
# 1995     176.22
# 1996     398.30
# 1997     402.05
# 1998     512.80
# 1999     502.39
# 2000     403.19
# 2001     662.96
# 2002     790.49
# 2003     715.46
# 2004     838.16
# 2005     919.35
# 2006    1041.56
# 2007    1221.57
# 2008    1357.39
# 2009    1334.40
# 2010    1200.81
# 2011    1031.92
# 2012     726.84
# 2013     736.09
# 2014     674.15
# 2015     528.70
# 2016     141.80
# 2017       0.10
# 2020       0.58
# Name: Total_Sales, dtype: float64

# %% [markdown]
# # Answer -

# %%
#plotting a graph
plt.figure(figsize=(20, 10))
p4=y.plot(kind='bar',title='Sales on different years')
plt.ylabel('Revenue Generated')
# Out:
# Text(0, 0.5, 'Revenue Generated')
